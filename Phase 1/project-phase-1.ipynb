# %% [markdown]
# <br>
# <font>
# <div dir=ltr align=center>
# <img src="https://cdn.freebiesupply.com/logos/large/2x/sharif-logo-png-transparent.png" width=150 height=150>
# <div dir=ltr align=center>
# <font color=0F5298 size=7>
#     Artificial Intelligence <br>
# <font color=2565AE size=5>
#     Computer Engineering Department <br>
#     Spring 2025<br>
# <font color=3C99D size=5>
#     Project-Phase1<br>
#     Image Segmentation<br>
# <font color=696880 size=4>
#     Shayan Baghayi Nejad-Armin Khosravi

# %% [markdown]
# <font size=5 color=cyan> Names: Mahan Masoumzade, Amir Mohammad Hamidi
#
# Student Numbers 402106518 402105932 </font>

# %% [markdown]
# # Introduction
#
# In this Project, we will become familiar with UNet architecture, Attention mechanism, and Residual blocks with the help of which we will build UNet, AttentionUNet, and ResidualAttentionUnet from scratch using PyTorch framework. The built models will be evaluated by various metrics such as accuracy, Iou score, and Dice score.

# %% [markdown]
# ### Environment Setup
#
# Here you will find the required packages. Feel free to add the list.

# %%
import os
import shutil
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import kagglehub
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch.optim import Adam
from tqdm import tqdm

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ### Hyperparameter Setting
#
# Place your hyperparameters' values in the cell below.

# %%
DATA_DIR = "/kaggle/input/massachusetts-roads-dataset"
IMAGE_SIZE = (512, 512)
BATCH_SIZE = 8
NUM_WORKERS = 2
LR = 0.001
NUM_EPOCHS = 40

# %% [markdown]
# # Data Preparation
#
# Our task is to segment the [Massachusetts Road Dataset](https://www.kaggle.com/datasets/balraj98/massachusetts-roads-dataset). You can download this dataset by placing your API Token from kaggle in ```~/.kaggle/``` folder (Instructions can be found in the Kaggle website) and then running the code below.

# %%
path = kagglehub.dataset_download("balraj98/massachusetts-roads-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/massachusetts-roads-dataset

# %% [markdown]
# If you are running on colab, it is highly recommended to save the dataset to your drive to avoid problems when disconnecting from runtime.

# %%
#from google.colab import drive

#drive.mount('/content/drive')

#shutil.copytree(path, '/content/drive/MyDrive/massachusetts-roads-dataset')

# %% [markdown]
# ### Loading Images
#
# Load the images and their corresponding masks in two separate lists. (The cell below might take some time to execute.)

# %%
import os
import numpy as np
from PIL import Image

def load_images_and_masks(images_path, masks_path, image_size):
    """
    Loads and preprocesses images and their corresponding masks.

    Args:
        images_path (str): Path to the directory containing input images.
        masks_path (str): Path to the directory containing corresponding masks.
        image_size (tuple): Desired size (width, height) to resize images and masks.

    Returns:
        images (np.array): Loaded and resized images.
        masks (np.array): Loaded and resized masks.
    """

    images = []
    masks = []

    for img_file, mask_file in zip(images_path, masks_path):
        # Load and convert
        img = Image.open(img_file).convert('RGB')
        mask = Image.open(mask_file).convert('L')

        # Resize
        img = img.resize(image_size)
        mask = mask.resize(image_size)

        # Convert to arrays
        img_array = np.array(img).astype(np.float32) / 255.0  # Normalize image
        mask_array = np.array(mask).astype(np.uint8)  # Binarize mask

        images.append(img_array)
        masks.append(mask_array)

    return np.array(images), np.array(masks)


# === Training ===
train_images_dir = os.path.join(DATA_DIR, 'tiff/train')
train_masks_dir = os.path.join(DATA_DIR, 'tiff/train_labels')

# Placeholder paths (can be used to store lists if needed later)
train_images_path = sorted([os.path.join(train_images_dir, fname) for fname in os.listdir(train_images_dir)])
train_masks_path = sorted([os.path.join(train_masks_dir, fname) for fname in os.listdir(train_masks_dir)])

# Load training data
train_images, train_masks = load_images_and_masks(train_images_path, train_masks_path, IMAGE_SIZE)

# === Validation ===
val_images_dir = os.path.join(DATA_DIR, 'tiff/val')
val_masks_dir = os.path.join(DATA_DIR, 'tiff/val_labels')

val_images_path = sorted([os.path.join(val_images_dir, fname) for fname in os.listdir(val_images_dir)])
val_masks_path = sorted([os.path.join(val_masks_dir, fname) for fname in os.listdir(val_masks_dir)])

# Load validation data
val_images, val_masks = load_images_and_masks(val_images_path, val_masks_path, IMAGE_SIZE)

# %% [markdown]
# ### Data Visualization
#
# Display the images and their masks for several samples.

# %%
import matplotlib.pyplot as plt

def visualize_images_and_masks(images, masks, n=5):
    """
    Visualizes 'n' images and their corresponding masks side by side.

    Args:
        images (array-like): Collection of input images (H, W, 3).
        masks (array-like): Collection of corresponding mask images (H, W).
        n (int): Number of image-mask pairs to display.
    """
    plt.figure(figsize=(10, 4 * n))

    for i in range(n):
        # Display image
        plt.subplot(n, 2, 2 * i + 1)
        plt.imshow(images[i])
        plt.title(f"Image {i+1}")
        plt.axis('off')

        # Display corresponding mask
        plt.subplot(n, 2, 2 * i + 2)
        plt.imshow(masks[i], cmap='gray')
        plt.title(f"Mask {i+1}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

visualize_images_and_masks(train_images, train_masks)

# %% [markdown]
# ### Dataset Creation
#
# Finally, we will make the dataset using the list of images we have stored.

# %%
class RoadDataset(Dataset):
    """
    Custom Dataset class for loading road images and their corresponding masks.

    Args:
        images (array-like): List or array of input images.
        masks (array-like): List or array of corresponding masks.
        image_transform (callable, optional): Transformation to apply to the images.
        mask_transform (callable, optional): Transformation to apply to the masks.
    """
    def __init__(self, images, masks, image_transform=None, mask_transform=None):
        self.images = images
        self.masks = masks
        self.image_transform = image_transform
        self.mask_transform = mask_transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        mask = self.masks[idx]
        
        if self.image_transform:
            image = self.image_transform(image)
        
        if self.mask_transform:
            mask = self.mask_transform(mask)
            
        return image, mask


# Define a function instead of lambda for better pickling
def threshold_mask(x):
    return (x > 0.5).long()

### Define your desired transformations
image_transform = transforms.Compose([
    transforms.ToTensor()
])

mask_transform = transforms.Compose([
    transforms.ToTensor(),
    threshold_mask
])


train_dataset = RoadDataset(train_images, train_masks, image_transform, mask_transform)
val_dataset   = RoadDataset(val_images, val_masks, image_transform, mask_transform)

# Set num_workers=0 to avoid multiprocessing issues with lambda functions
train_loader  = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
val_loader    = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# # UNet
#
# Before proceeding, it is necessary to understand the idea behind UNet. In order to avoid too much details in this notebook, you can read the complete paper for UNet from [this link](https://arxiv.org/pdf/1505.04597).
#
# The overall structure of UNet is provided in the image below.
#
# ![UNet Architecture](https://viso.ai/wp-content/uploads/2024/04/unet-process.png)

# %% [markdown]
# ### Convolution Block
#
# Convolution block is used at each level of UNet.

# %%
class ConvBlock(nn.Module):
    """
    A convolutional block consisting of multiple layers (e.g., Conv2D, BatchNorm, ReLU).

    Args:
        in_channel (int): Number of input channels.
        out_channel (int): Number of output channels.
    """
    def __init__(self, in_channel, out_channel):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channel, out_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channel),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channel, out_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channel),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
      return self.conv(x)

# %% [markdown]
# ### Up Convoluitional Block
#
# We use another block to upsample the latent vector.

# %%
class UpConvBlock(nn.Module):
    """
    An upsampling block used in decoder parts of segmentation networks like U-Net.

    Args:
        in_channel (int): Number of input channels.
        out_channel (int): Number of output channels.
    """
    def __init__(self, in_channel, out_channel):
      super().__init__()
      self.upconv = nn.Sequential(
            nn.ConvTranspose2d(in_channel, out_channel, kernel_size=2, stride=2),
            nn.BatchNorm2d(out_channel),
            nn.ReLU(inplace=True)
      )

    def forward(self, x):
      return self.upconv(x)

# %% [markdown]
# ### Complete UNet Structure
#
# Now using the ```ConvBlock``` and ```UpConvBlock``` you created, complete the UNet architecture.

# %%
class UNet(nn.Module):
    """
    U-Net architecture for image segmentation tasks.

    Args:
        in_channel (int): Number of input channels (e.g., 3 for RGB images).
        out_channel (int): Number of output channels (e.g., 1 for binary segmentation).
        filter (list): List of filter sizes for each level of the encoder/decoder.
    """
    def __init__(self, in_channel=3, out_channel=1, filters=[64, 128, 256, 512]):
        super().__init__()
        # there are 4 encoder levels and 4 decoder levels : 
        
        # Encoder :
        self.conv1 = ConvBlock(in_channel, filters[0])
        self.pool1 = nn.MaxPool2d(2)

        self.conv2 = ConvBlock(filters[0], filters[1])
        self.pool2 = nn.MaxPool2d(2)

        self.conv3 = ConvBlock(filters[1], filters[2])
        self.pool3 = nn.MaxPool2d(2)

        self.conv4 = ConvBlock(filters[2], filters[3])
        self.pool4 = nn.MaxPool2d(2)

        # Bottleneck :
        self.bottleneck = ConvBlock(filters[3] , 2 * filters[3])

        #Decoder part : 
        self.up4 = UpConvBlock(2 * filters[3], filters[3])
        self.dec4 = ConvBlock(2 * filters[3], filters[3])

        self.up3 = UpConvBlock(filters[3], filters[2])
        self.dec3 = ConvBlock(filters[3], filters[2])

        self.up2 = UpConvBlock(filters[2], filters[1])
        self.dec2 = ConvBlock(filters[2], filters[1])

        self.up1 = UpConvBlock(filters[1], filters[0])
        self.dec1 = ConvBlock(filters[1], filters[0])
        
        self.final_conv = nn.Conv2d(filters[0], out_channel, kernel_size=1)

        self.activation = nn.Sigmoid()

    def forward(self, x):
        # Encoder :
        x1 = self.conv1(x)
        x2 = self.conv2(self.pool1(x1))
        x3 = self.conv3(self.pool2(x2))
        x4 = self.conv4(self.pool3(x3))

        # Bottleneck : 
        x5 = self.bottleneck(self.pool4(x4))

        # Decoder :
        d4 = self.up4(x5)
        d4 = self.dec4(torch.cat([x4, d4], dim=1))

        d3 = self.up3(d4)
        d3 = self.dec3(torch.cat([x3, d3], dim=1))

        d2 = self.up2(d3)
        d2 = self.dec2(torch.cat([x2, d2], dim=1))

        d1 = self.up1(d2)
        d1 = self.dec1(torch.cat([x1, d1], dim=1))

        out = self.final_conv(d1)

        #apply activation : 
        return self.activation(out)

# %% [markdown]
# # Attention UNet

# %% [markdown]
# ### Attention Mechanism
#
# Attention UNet uses this mechanism to know what part the image is more important to attend to. You can read about this mechanism from [this link](https://arxiv.org/pdf/1706.03762). The Attention mechanism in UNet is described in [this paper](https://arxiv.org/pdf/1804.03999).
#
#
# ![Attention](https://www.researchgate.net/publication/373655981/figure/fig3/AS:11431281186315360@1693879045519/Visualization-of-attention-blocks-reveals-their-functionality-While-the-self-attention.png)

# %%
class AttentionBlock(nn.Module):
    """
    Attention block for focusing on relevant features in skip connections.

    Args:
        f_g (int): Number of channels in the gating signal (from decoder).
        f_l (int): Number of channels in the skip connection input (from encoder).
        f_int (int): Number of intermediate channels used within the attention block.
    """
    def __init__(self, f_g, f_l, f_int):
        super().__init__()

        # 1x1 conv to reduce channels of decoder features (gating signal)
        self.w_g = nn.Sequential(
            nn.Conv2d(f_g, f_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(f_int)
        )
        
        # 1x1 conv to reduce channels of encoder features (skip connection)
        self.w_x = nn.Sequential(
            nn.Conv2d(f_l, f_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(f_int)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(f_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )

        self.act = nn.ReLU(inplace=True)


    def forward(self, g, x):
        # g: decoder feature
        # x: encoder skip connection feature

        g1 = self.w_g(g)  # shape: (B, f_int, H, W)
        x1 = self.w_x(x)  # shape: (B, f_int, H, W)

        # Add and apply ReLU
        psi = self.act(g1 + x1)

        # Get attention map
        psi = self.psi(psi)  # shape: (B, 1, H, W)

        # Apply attention map to encoder features
        return x * psi

# %% [markdown]
# Now use the ```AttentionBlock``` to inherit [Attention UNet](https://arxiv.org/pdf/1804.03999) from UNet.
#
# ![Attention UNet](https://www.researchgate.net/publication/347344899/figure/fig6/AS:971357475069952@1608601077414/The-architecture-of-Attention-U-Net-Attention-gate-selects-features-by-using-the.png)

# %%
class AttentionUNet(UNet):  # Inherits from UNet
    """
    Attention U-Net architecture which extends the basic U-Net
    by integrating attention blocks in the skip connections.

    Args:
        in_channel (int): Number of input channels.
        out_channel (int): Number of output channels.
        filter_sizes (list): List of filter sizes for each level.
    """
    def __init__(self, in_channel=3, out_channel=1, filter_sizes=[64, 128, 256, 512]):
        super().__init__(in_channel, out_channel, filter_sizes)
        
        # Define attention blocks for each decoder level
        self.att4 = AttentionBlock(f_g = filter_sizes[3], f_l = filter_sizes[3], f_int = filter_sizes[2])
        self.att3 = AttentionBlock(f_g = filter_sizes[2], f_l = filter_sizes[2], f_int = filter_sizes[1])
        self.att2 = AttentionBlock(f_g = filter_sizes[1], f_l = filter_sizes[1], f_int = filter_sizes[0])
        self.att1 = AttentionBlock(f_g = filter_sizes[0], f_l = filter_sizes[0], f_int = filter_sizes[0] // 2)

    def forward(self, x):
        # Encoder
        x1 = self.conv1(x)
        x2 = self.conv2(self.pool1(x1))
        x3 = self.conv3(self.pool2(x2))
        x4 = self.conv4(self.pool3(x3))

        # Bottleneck
        x5 = self.bottleneck(self.pool4(x4))

        # Decoder with attention on skip connections
        g4 = self.up4(x5)
        x4_att = self.att4(g4, x4)
        d4 = self.dec4(torch.cat([x4_att, g4], dim=1))

        g3 = self.up3(d4)
        x3_att = self.att3(g3, x3)
        d3 = self.dec3(torch.cat([x3_att, g3], dim=1))

        g2 = self.up2(d3)
        x2_att = self.att2(g2, x2)
        d2 = self.dec2(torch.cat([x2_att, g2], dim=1))

        g1 = self.up1(d2)
        x1_att = self.att1(g1, x1)
        d1 = self.dec1(torch.cat([x1_att, g1], dim=1))

        out = self.final_conv(d1)
        return self.activation(out)

# %% [markdown]
# # Residual Attention UNet
#
# We will add residual blocks to the attention for better gradient flow. You can read more about residual blocks [here](https://arxiv.org/pdf/1512.03385).
#
# <img src="https://dfzljdn9uc3pi.cloudfront.net/2023/cs-1302/1/fig-1-full.png" width="400" alt="ResUNet Architecture">

# %%
class ResidualConvBlock(nn.Module):
    """
    Residual convolutional block with skip connection.

    Args:
        in_channel (int): Number of input channels.
        out_channel (int): Number of output channels.
    """
    def __init__(self, in_channel, out_channel):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channel, out_channel, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channel),
            nn.ReLU(inplace=True)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(out_channel, out_channel, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channel),
            nn.ReLU(inplace=True)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(out_channel, out_channel, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channel)
        )
        self.shortcut = nn.Sequential(
            nn.Conv2d(in_channel, out_channel, kernel_size=3, padding=1, bias=False),  # Conv3x3 shortcut
            nn.BatchNorm2d(out_channel)
        ) if in_channel != out_channel else nn.Identity()

        self.act = nn.ReLU(inplace=True)
        
    def forward(self, x):
        identity = self.shortcut(x)
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)
        out += identity
        out = self.act(out)
        return out

# %% [markdown]
# Use ```ResidualConvBlock``` to construct Residual Attention Unet.

# %%
class ResidualAttentionUNet(AttentionUNet):
    """
    Residual Attention U-Net combining residual blocks with attention mechanisms.

    Args:
        in_channel (int): Number of input channels.
        out_channel (int): Number of output channels.
        filter_sizes (list): List of filter sizes for each level.
    """
    def __init__(self, in_channel=3, out_channel=1, filter_sizes=[64, 128, 256, 512]):
        super().__init__(in_channel, out_channel, filter_sizes)
        
        self.conv1 = ResidualConvBlock(in_channel, filter_sizes[0])
        self.conv2 = ResidualConvBlock(filter_sizes[0], filter_sizes[1])
        self.conv3 = ResidualConvBlock(filter_sizes[1], filter_sizes[2])
        self.conv4 = ResidualConvBlock(filter_sizes[2], filter_sizes[3])

        self.bottleneck = ResidualConvBlock(filter_sizes[3], 2 * filter_sizes[3])
        
        # Match the decoder blocks with what's expected in UNet
        self.up4 = UpConvBlock(2 * filter_sizes[3], filter_sizes[3])
        self.up3 = UpConvBlock(filter_sizes[3], filter_sizes[2])
        self.up2 = UpConvBlock(filter_sizes[2], filter_sizes[1])
        self.up1 = UpConvBlock(filter_sizes[1], filter_sizes[0])
        
        self.dec4 = ResidualConvBlock(2 * filter_sizes[3], filter_sizes[3])
        self.dec3 = ResidualConvBlock(2 * filter_sizes[2], filter_sizes[2])
        self.dec2 = ResidualConvBlock(2 * filter_sizes[1], filter_sizes[1])
        self.dec1 = ResidualConvBlock(2 * filter_sizes[0], filter_sizes[0])

    def forward(self, x):
        # Encoder
        x1 = self.conv1(x)
        x2 = self.conv2(self.pool1(x1))
        x3 = self.conv3(self.pool2(x2))
        x4 = self.conv4(self.pool3(x3))

        # Bottleneck
        x5 = self.bottleneck(self.pool4(x4))

        # Decoder with attention on skip connections
        g4 = self.up4(x5)
        x4_att = self.att4(g4, x4)
        d4 = self.dec4(torch.cat([x4_att, g4], dim=1))

        g3 = self.up3(d4)
        x3_att = self.att3(g3, x3)
        d3 = self.dec3(torch.cat([x3_att, g3], dim=1))

        g2 = self.up2(d3)
        x2_att = self.att2(g2, x2)
        d2 = self.dec2(torch.cat([x2_att, g2], dim=1))

        g1 = self.up1(d2)
        x1_att = self.att1(g1, x1)
        d1 = self.dec1(torch.cat([x1_att, g1], dim=1))

        out = self.final_conv(d1)
        return self.activation(out)

# %% [markdown]
# # Training
#
# Now it is time to train the model on training data.

# %% [markdown]
# ### Loss Function
#
# We will be using the sum of [Dice Score](https://oecd.ai/en/catalogue/metrics/dice-score#:~:text=The%20Dice%20score%20is%20calculated,sizes%20of%20the%20two%20sets.), [Iou Score](https://www.v7labs.com/blog/intersection-over-union-guide), and Binary Cross Entropy as loss function. You can read about the mentioned scores in the provided links.
#
# <font color=cyan><b> Note: Do Not Change The ```OverallLoss``` Function as it is used for measuring you model's performance.</b></font>

# %%
### DICE LOSS
class DiceLoss(nn.Module):
    """
    Dice Loss for measuring overlap between predicted and ground truth masks.
    Particularly useful for imbalanced classes in segmentation tasks.

    Args:
        smooth (float): Small constant to avoid division by zero.
    """
    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, pred, real):
        #flatten tensors : 
        P = pred.view(pred.size(0) , -1)
        R = real.view(real.size(0) , -1)
        
        #dice_coef = 2 * |I| / |P| + |R|
        intersection = (P * R).sum(dim = 1)
        Sum = P.sum(dim = 1) + R.sum(dim = 1)
        
        dice_coeff = (2 * intersection + self.smooth) / (Sum + self.smooth)
        dice_coeff = dice_coeff.mean()
        return 1 - dice_coeff


### Iou Loss
class IouLoss(nn.Module):
    """
    Intersection over Union (IoU) Loss for segmentation evaluation.
    Measures the overlap between predicted and ground truth masks.

    Args:
        smooth (float): Small constant to avoid division by zero.
    """
    def __init__(self, smooth=1e-6):
        super(IouLoss, self).__init__()
        self.smooth = smooth

    def forward(self, pred, real):
         #flatten tensors : 
        P = pred.view(pred.size(0) , -1)
        R = real.view(real.size(0) , -1)
        
        #iou_coef = |I| / |U|
        intersection = (P * R).sum(dim = 1)
        union = P.sum(dim = 1) + R.sum(dim = 1) - intersection
        
        iou_coeff = (intersection + self.smooth)/(union + self.smooth)
        iou_coeff = iou_coeff.mean()
        return 1 - iou_coeff


### Overall Loss (DO NOT CHANGE)
class OverallLoss(nn.Module):
    """
    Combined loss function that sums Dice loss, IoU loss, and Binary Cross-Entropy loss.

    Args:
        smooth (float): Small constant to avoid division by zero.
    """
    def __init__(self, smooth=1e-6):
        super(OverallLoss, self).__init__()
        self.dice_loss = DiceLoss(smooth)
        self.iou_loss = IouLoss(smooth)
        self.bce_loss = nn.BCELoss()

    def forward(self, pred, real):
        dice = self.dice_loss(pred, real)
        iou = self.iou_loss(pred, real)
        bce = self.bce_loss(pred, real)

        return dice, iou, bce, dice+iou+bce

# %% [markdown]
# ### Training Epoch
#
# Complete the function below to train the model for one epoch.

# %% [markdown]
# Design a function for evaluation after each training phase.

# %%
def train_one_epoch(model, optimizer, criterion, data_loader, scheduler=None, device='cuda'):
    """
    Trains the model for one epoch.

    Args:
        model (nn.Module): The neural network model to train.
        optimizer (torch.optim.Optimizer): Optimizer for updating model parameters.
        criterion (nn.Module): Loss function to compute the loss.
        data_loader (DataLoader): DataLoader providing training batches.
        scheduler (optional): Learning rate scheduler.
        device (str): Device to run the training on ('cuda' or 'cpu').

    Returns:
        float: Average loss over the epoch.
    """

    total_loss = 0.0
    model.train()
    
    # Create progress bar with tqdm to show training progress
    progress_bar = tqdm(data_loader, desc="Training", leave=True)
    
    for i, (img, mask) in enumerate(progress_bar):
        # Move the image and mask to device
        img = img.to(device, non_blocking=True)
        mask = mask.to(device, non_blocking=True).float()
        
        # Set the gradients to zero
        optimizer.zero_grad()
        
        # Predict the mask using the model
        pred = model(img)
        
        # Compute the loss
        _, _, _, loss = criterion.forward(pred, mask)
        
        # Compute gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        if scheduler:
            # Schedule the learning rate
            scheduler.step()

        # Update the progress bar with current loss
        progress_bar.set_postfix(loss=f"{loss.item():.4f}")
        total_loss += loss.item()

    return total_loss/len(data_loader)

# %%
def evaluate_model(model, criterion, data_loader, device='cuda'):
    """
    Evaluates the model on validation or test data.

    Args:
        model (nn.Module): The neural network model to evaluate.
        criterion (nn.Module): Loss function to compute evaluation metrics.
        data_loader (DataLoader): DataLoader providing evaluation batches.
        device (str): Device to run evaluation on ('cuda' or 'cpu').

    Returns:
        tuple: Average loss, average IoU score, and average Dice score over the dataset.
    """
    total_loss = 0.0
    iou_score = 0.0
    dice_score = 0.0
    model.eval()

    with torch.no_grad():
        # Create progress bar with tqdm to show evaluation progress
        progress_bar = tqdm(data_loader, desc="Evaluating", leave=True)
        
        for i, (img, mask) in enumerate(progress_bar):
            # Move the image and mask to device
            img = img.to(device)
            mask = mask.to(device).float()

            # Predict the mask
            pred = model(img)

            # Compute the loss
            dice_loss, iou_loss, bce_loss, overall_loss = criterion(pred, mask)

            # Update metrics
            total_loss += overall_loss.item()
            iou_score += 1 - iou_loss.item()
            dice_score += 1 - dice_loss.item()
            
            # Update progress bar
            progress_bar.set_postfix(loss=f"{overall_loss.item():.4f}", iou=f"{1-iou_loss.item():.4f}")

        total_loss /= len(data_loader)
        iou_score /= len(data_loader)
        dice_score /= len(data_loader)

    return total_loss, iou_score, dice_score

# %% [markdown]
# # Model Training
#
# ### UNet
# Create an instance of UNet and train it. Then report the results.
#
# <b><font color=red>Note: your models need to satisfy below conditions to get complete score.</font></b>
#
# <table style="width: 100%; font-size: 18px; border-collapse: collapse; margin: 15px 0;">
#   <tr>
#     <th style="text-align: left; padding: 8px; border-bottom: 2px solid #ddd;">Model</th>
#     <th style="text-align: right; padding: 8px; border-bottom: 2px solid #ddd;">Validation Loss</th>
#     <th style="text-align: right; padding: 8px; border-bottom: 2px solid #ddd;">Iou Score</th>
#     <th style="text-align: right; padding: 8px; border-bottom: 2px solid #ddd;">Dice Score</th>
#   </tr>
#   <tr>
#     <td style="padding: 8px; border-bottom: 1px solid #ddd;">UNet</td>
#     <td style="text-align: right; padding: 8px; border-bottom: 1px solid #ddd;">&lt; 1.0</td>
#     <td style="text-align: right; padding: 8px; border-bottom: 1px solid #ddd;">&gt; 0.5</td>
#     <td style="text-align: right; padding: 8px; border-bottom: 1px solid #ddd;">&gt; 0.6</td>
#   </tr>
#   <tr>
#     <td style="padding: 8px; border-bottom: 1px solid #ddd;">Attention UNet</td>
#     <td style="text-align: right; padding: 8px; border-bottom: 1px solid #ddd;">&lt; 0.9</td>
#     <td style="text-align: right; padding: 8px; border-bottom: 1px solid #ddd;">&gt; 0.6</td>
#     <td style="text-align: right; padding: 8px; border-bottom: 1px solid #ddd;">&gt; 0.65</td>
#   </tr>
#   <tr>
#     <td style="padding: 8px;">Residual Attention UNet</td>
#     <td style="text-align: right; padding: 8px;">&lt; 0.8</td>
#     <td style="text-align: right; padding: 8px;">&gt; 0.65</td>
#     <td style="text-align: right; padding: 8px;">&gt; 0.7</td>
#   </tr>
# </table>

# %%
# We stopped the model after it reached reqired results due to time and resource problems

unet = UNet().to(device)
criterion = OverallLoss()
num_gpus = torch.cuda.device_count()

if num_gpus > 1:
    unet = nn.DataParallel(unet)
# Using optimizer with weight decay for better regularization
optimizer = Adam(unet.parameters(), lr=LR, weight_decay=1e-5)
# Add a scheduler for learning rate adjustment (removed verbose parameter)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

best_loss = 100.0
for i in range(NUM_EPOCHS):
    train_loss = train_one_epoch(unet, optimizer, criterion, train_loader, None, device)
    val_loss, iou_score, dice_score = evaluate_model(unet, criterion, val_loader, device)
    
    # Step the scheduler based on validation loss
    scheduler.step(val_loss)

    if val_loss < best_loss:
        best_loss = val_loss
        torch.save(unet.state_dict(), "best_unet.pth")

    print(f"Iteration {i+1}/{NUM_EPOCHS}: "
          f"Train Loss: {train_loss:.2f} | "
          f"Val Loss: {val_loss:.2f} | "
          f"Iou Score: {iou_score:.2f} | "
          f"Dice Score: {dice_score:.2f}")
# Out:
# Training: 100%|██████████| 139/139 [02:30<00:00,  1.08s/it, loss=1.6080]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.75it/s, iou=0.3062, loss=1.5046]
# Iteration 1/30: Train Loss: 1.89 | Val Loss: 1.49 | Iou Score: 0.32 | Dice Score: 0.48
# Training: 100%|██████████| 139/139 [02:39<00:00,  1.15s/it, loss=1.4137]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.67it/s, iou=0.4890, loss=0.9893]
# Iteration 2/30: Train Loss: 1.33 | Val Loss: 1.04 | Iou Score: 0.47 | Dice Score: 0.64
# Training: 100%|██████████| 139/139 [02:40<00:00,  1.16s/it, loss=1.6484]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.72it/s, iou=0.4601, loss=1.0744]
# Iteration 3/30: Train Loss: 1.20 | Val Loss: 1.15 | Iou Score: 0.44 | Dice Score: 0.61
# Training: 100%|██████████| 139/139 [02:41<00:00,  1.16s/it, loss=1.2601]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.69it/s, iou=0.5068, loss=0.9575]
# Iteration 4/30: Train Loss: 1.15 | Val Loss: 1.03 | Iou Score: 0.49 | Dice Score: 0.65
# Training: 100%|██████████| 139/139 [02:40<00:00,  1.16s/it, loss=0.9494]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.68it/s, iou=0.5318, loss=0.9100]
# Iteration 5/30: Train Loss: 1.12 | Val Loss: 1.00 | Iou Score: 0.50 | Dice Score: 0.67
# Training: 100%|██████████| 139/139 [02:41<00:00,  1.16s/it, loss=0.9510]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.67it/s, iou=0.5586, loss=0.8472]
# Iteration 6/30: Train Loss: 1.10 | Val Loss: 0.95 | Iou Score: 0.52 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [02:41<00:00,  1.16s/it, loss=1.0322]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.64it/s, iou=0.5601, loss=0.8502]
# Iteration 7/30: Train Loss: 1.07 | Val Loss: 0.91 | Iou Score: 0.54 | Dice Score: 0.70
# Training: 100%|██████████| 139/139 [02:41<00:00,  1.16s/it, loss=1.0939]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.71it/s, iou=0.5473, loss=0.8828]
# Iteration 8/30: Train Loss: 1.06 | Val Loss: 0.99 | Iou Score: 0.52 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [02:41<00:00,  1.16s/it, loss=1.4465]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.70it/s, iou=0.5686, loss=0.8298]
# Iteration 9/30: Train Loss: 1.05 | Val Loss: 0.89 | Iou Score: 0.55 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [02:41<00:00,  1.16s/it, loss=1.1568]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.69it/s, iou=0.5777, loss=0.8066]
# Iteration 10/30: Train Loss: 1.04 | Val Loss: 0.87 | Iou Score: 0.55 | Dice Score: 0.71
# Training:  28%|██▊       | 39/139 [00:46<01:59,  1.20s/it, loss=1.1287]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_36/4133574761.py in <cell line: 0>()
#      12 best_loss = 100.0
#      13 for i in range(NUM_EPOCHS):
# ---> 14     train_loss = train_one_epoch(unet, optimizer, criterion, train_loader, None, device)
#      15     val_loss, iou_score, dice_score = evaluate_model(unet, criterion, val_loader, device)
#      16
#
# /tmp/ipykernel_36/2741467668.py in train_one_epoch(model, optimizer, criterion, data_loader, scheduler, device)
#      46
#      47         # Update the progress bar with current loss
# ---> 48         progress_bar.set_postfix(loss=f"{loss.item():.4f}")
#      49         total_loss += loss.item()
#      50
#
# KeyboardInterrupt:

# %% [markdown]
# Now do the same for Attention UNet and Reidual Attention UNet.

# %%
torch.cuda.empty_cache()
attention_unet = AttentionUNet().to(device)

num_gpus = torch.cuda.device_count()

if num_gpus > 1:
    attention_unet = nn.DataParallel(attention_unet)
                                    
criterion = OverallLoss()
# Using optimizer with weight decay
optimizer = Adam(attention_unet.parameters(), lr=LR, weight_decay=1e-5)
# Add learning rate scheduler (removed verbose parameter)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)
best_loss = 100.0
for i in range(NUM_EPOCHS):
    train_loss = train_one_epoch(attention_unet, optimizer, criterion, train_loader, None, device)
    val_loss, iou_score, dice_score = evaluate_model(attention_unet, criterion, val_loader, device)
    
    # Step scheduler
    scheduler.step(val_loss)

    if val_loss < best_loss:
        best_loss = val_loss
        torch.save(attention_unet.state_dict(), "best_attention_unet.pth")

    print(f"Iteration {i+1}/{NUM_EPOCHS}: "
          f"Train Loss: {train_loss:.2f} | "
          f"Val Loss: {val_loss:.2f} | "
          f"Iou Score: {iou_score:.2f} | "
          f"Dice Score: {dice_score:.2f}")
# Out:
# Training: 100%|██████████| 139/139 [03:01<00:00,  1.30s/it, loss=1.4350]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.48it/s, iou=0.3362, loss=1.3177]
# Iteration 1/40: Train Loss: 1.87 | Val Loss: 1.37 | Iou Score: 0.32 | Dice Score: 0.48
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=1.1667]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s, iou=0.4821, loss=1.0187]
# Iteration 2/40: Train Loss: 1.30 | Val Loss: 1.06 | Iou Score: 0.47 | Dice Score: 0.64
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.9146]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.44it/s, iou=0.4885, loss=1.0092]
# Iteration 3/40: Train Loss: 1.18 | Val Loss: 1.07 | Iou Score: 0.47 | Dice Score: 0.64
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=1.0724]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.40it/s, iou=0.5406, loss=0.8895]
# Iteration 4/40: Train Loss: 1.13 | Val Loss: 0.96 | Iou Score: 0.52 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.9821]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s, iou=0.5460, loss=0.8874]
# Iteration 5/40: Train Loss: 1.10 | Val Loss: 0.97 | Iou Score: 0.52 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=1.4228]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s, iou=0.5566, loss=0.8561]
# Iteration 6/40: Train Loss: 1.08 | Val Loss: 0.96 | Iou Score: 0.52 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=1.0121]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.40it/s, iou=0.5813, loss=0.8021]
# Iteration 7/40: Train Loss: 1.07 | Val Loss: 0.88 | Iou Score: 0.55 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.9854]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s, iou=0.5788, loss=0.8072]
# Iteration 8/40: Train Loss: 1.04 | Val Loss: 0.87 | Iou Score: 0.56 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.8212]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.5780, loss=0.8090]
# Iteration 9/40: Train Loss: 1.04 | Val Loss: 0.89 | Iou Score: 0.55 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=1.0178]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s, iou=0.5892, loss=0.7871]
# Iteration 10/40: Train Loss: 1.03 | Val Loss: 0.86 | Iou Score: 0.56 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.8234]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.5899, loss=0.7795]
# Iteration 11/40: Train Loss: 1.01 | Val Loss: 0.86 | Iou Score: 0.56 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=1.0326]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s, iou=0.6022, loss=0.7649]
# Iteration 12/40: Train Loss: 1.01 | Val Loss: 0.84 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.9287]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s, iou=0.5833, loss=0.7978]
# Iteration 13/40: Train Loss: 1.01 | Val Loss: 0.85 | Iou Score: 0.56 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [03:00<00:00,  1.30s/it, loss=0.7065]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.5667, loss=0.8415]
# Iteration 14/40: Train Loss: 1.00 | Val Loss: 0.93 | Iou Score: 0.53 | Dice Score: 0.69
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=0.8377]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.40it/s, iou=0.6059, loss=0.7515]
# Iteration 15/40: Train Loss: 0.99 | Val Loss: 0.82 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=0.6951]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s, iou=0.5932, loss=0.7830]
# Iteration 16/40: Train Loss: 0.99 | Val Loss: 0.86 | Iou Score: 0.57 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=0.6608]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s, iou=0.6000, loss=0.7704]
# Iteration 17/40: Train Loss: 0.98 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=0.8362]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.6025, loss=0.7643]
# Iteration 18/40: Train Loss: 0.98 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:59<00:00,  1.29s/it, loss=0.8874]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.6058, loss=0.7614]
# Iteration 19/40: Train Loss: 0.97 | Val Loss: 0.84 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:58<00:00,  1.28s/it, loss=1.0543]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.5939, loss=0.7797]
# Iteration 20/40: Train Loss: 0.96 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:58<00:00,  1.29s/it, loss=0.7664]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.6064, loss=0.7563]
# Iteration 21/40: Train Loss: 0.96 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:58<00:00,  1.28s/it, loss=0.7366]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s, iou=0.6183, loss=0.7284]
# Iteration 22/40: Train Loss: 0.93 | Val Loss: 0.80 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:57<00:00,  1.28s/it, loss=0.7314]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s, iou=0.6200, loss=0.7264]
# Iteration 23/40: Train Loss: 0.92 | Val Loss: 0.79 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [02:58<00:00,  1.28s/it, loss=0.7290]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6206, loss=0.7201]
# Iteration 24/40: Train Loss: 0.92 | Val Loss: 0.78 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [02:57<00:00,  1.28s/it, loss=0.7935]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s, iou=0.6178, loss=0.7341]
# Iteration 25/40: Train Loss: 0.91 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:58<00:00,  1.28s/it, loss=1.1234]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.47it/s, iou=0.6180, loss=0.7323]
# Iteration 26/40: Train Loss: 0.91 | Val Loss: 0.80 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:57<00:00,  1.27s/it, loss=0.8919]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.46it/s, iou=0.6060, loss=0.7595]
# Iteration 27/40: Train Loss: 0.90 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=1.0525]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.6045, loss=0.7598]
# Iteration 28/40: Train Loss: 0.91 | Val Loss: 0.84 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [02:57<00:00,  1.27s/it, loss=0.6281]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.46it/s, iou=0.5870, loss=0.7949]
# Iteration 29/40: Train Loss: 0.90 | Val Loss: 0.88 | Iou Score: 0.56 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [02:57<00:00,  1.27s/it, loss=0.7907]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.44it/s, iou=0.6116, loss=0.7564]
# Iteration 30/40: Train Loss: 0.90 | Val Loss: 0.82 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=0.8407]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6109, loss=0.7505]
# Iteration 31/40: Train Loss: 0.88 | Val Loss: 0.82 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:57<00:00,  1.28s/it, loss=0.8750]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6131, loss=0.7459]
# Iteration 32/40: Train Loss: 0.87 | Val Loss: 0.82 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=0.9927]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.47it/s, iou=0.6238, loss=0.7223]
# Iteration 33/40: Train Loss: 0.86 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=1.1079]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6185, loss=0.7372]
# Iteration 34/40: Train Loss: 0.86 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=1.1430]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6222, loss=0.7244]
# Iteration 35/40: Train Loss: 0.85 | Val Loss: 0.79 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=0.7469]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6198, loss=0.7330]
# Iteration 36/40: Train Loss: 0.85 | Val Loss: 0.81 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=0.8463]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.44it/s, iou=0.6152, loss=0.7448]
# Iteration 37/40: Train Loss: 0.84 | Val Loss: 0.82 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=0.9082]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.6237, loss=0.7256]
# Iteration 38/40: Train Loss: 0.83 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=0.6418]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s, iou=0.6185, loss=0.7382]
# Iteration 39/40: Train Loss: 0.83 | Val Loss: 0.81 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [02:56<00:00,  1.27s/it, loss=1.0255]
# Evaluating: 100%|██████████| 2/2 [00:00<00:00,  2.45it/s, iou=0.6167, loss=0.7401]
# Iteration 40/40: Train Loss: 0.83 | Val Loss: 0.81 | Iou Score: 0.59 | Dice Score: 0.74

# %% [markdown]
# For Residual Attention UNet, plot the changes in train and validation loss.

# %%
torch.cuda.empty_cache()

resattn_unet = ResidualAttentionUNet().to(device)
criterion = OverallLoss()
num_gpus = torch.cuda.device_count()
if num_gpus > 1:
    resattn_unet = nn.DataParallel(resattn_unet)
# You can use other optimizers or Adam optimizer with customized weight decay, b1, or b2
optimizer = Adam(resattn_unet.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)
train_losses = []
val_losses = []
best_loss = 100.0
for i in range(NUM_EPOCHS):
    train_loss = train_one_epoch(resattn_unet, optimizer, criterion, train_loader)
    val_loss, iou_score, dice_score = evaluate_model(resattn_unet, criterion, val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    scheduler.step(val_loss)
    if val_loss < best_loss:
        torch.save(resattn_unet.state_dict(), "best_residual_attention_unet.pth")

    print(f"Iteration {i+1}/{NUM_EPOCHS}: "
          f"Train Loss: {train_loss:.2f} | "
          f"Val Loss: {val_loss:.2f} | "
          f"Iou Score: {iou_score:.2f} | "
          f"Dice Score: {dice_score:.2f}")
# Out:
# Training: 100%|██████████| 139/139 [04:43<00:00,  2.04s/it, loss=1.3082]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.43it/s, iou=0.4725, loss=1.0260]
# Iteration 1/30: Train Loss: 1.62 | Val Loss: 1.11 | Iou Score: 0.45 | Dice Score: 0.61
# Training: 100%|██████████| 139/139 [04:58<00:00,  2.14s/it, loss=1.1298]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.5373, loss=0.8931]
# Iteration 2/30: Train Loss: 1.19 | Val Loss: 0.97 | Iou Score: 0.51 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [04:58<00:00,  2.15s/it, loss=0.9236]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.5493, loss=0.8729]
# Iteration 3/30: Train Loss: 1.12 | Val Loss: 0.95 | Iou Score: 0.52 | Dice Score: 0.68
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.9702]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.5627, loss=0.8418]
# Iteration 4/30: Train Loss: 1.09 | Val Loss: 0.92 | Iou Score: 0.54 | Dice Score: 0.70
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.7391]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.5075, loss=0.9631]
# Iteration 5/30: Train Loss: 1.06 | Val Loss: 1.01 | Iou Score: 0.50 | Dice Score: 0.66
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=1.3076]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.5855, loss=0.7918]
# Iteration 6/30: Train Loss: 1.05 | Val Loss: 0.86 | Iou Score: 0.56 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.9783]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.5861, loss=0.7962]
# Iteration 7/30: Train Loss: 1.04 | Val Loss: 0.86 | Iou Score: 0.57 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.7986]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s, iou=0.5933, loss=0.7783]
# Iteration 8/30: Train Loss: 1.01 | Val Loss: 0.84 | Iou Score: 0.57 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.15s/it, loss=0.9856]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s, iou=0.5832, loss=0.8004]
# Iteration 9/30: Train Loss: 1.00 | Val Loss: 0.89 | Iou Score: 0.55 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.8680]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6032, loss=0.7559]
# Iteration 10/30: Train Loss: 0.99 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.15s/it, loss=0.9521]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.6127, loss=0.7414]
# Iteration 11/30: Train Loss: 0.99 | Val Loss: 0.80 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=1.1523]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s, iou=0.5801, loss=0.8088]
# Iteration 12/30: Train Loss: 0.98 | Val Loss: 0.91 | Iou Score: 0.54 | Dice Score: 0.70
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.7464]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.5948, loss=0.7779]
# Iteration 13/30: Train Loss: 0.97 | Val Loss: 0.83 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.7962]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6111, loss=0.7386]
# Iteration 14/30: Train Loss: 0.96 | Val Loss: 0.81 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=1.3257]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.5928, loss=0.7721]
# Iteration 15/30: Train Loss: 0.96 | Val Loss: 0.84 | Iou Score: 0.57 | Dice Score: 0.72
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.8365]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.5782, loss=0.8115]
# Iteration 16/30: Train Loss: 0.95 | Val Loss: 0.91 | Iou Score: 0.55 | Dice Score: 0.70
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.8659]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.6062, loss=0.7496]
# Iteration 17/30: Train Loss: 0.96 | Val Loss: 0.82 | Iou Score: 0.58 | Dice Score: 0.73
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=1.3362]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.6258, loss=0.7119]
# Iteration 18/30: Train Loss: 0.93 | Val Loss: 0.78 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.8073]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6186, loss=0.7346]
# Iteration 19/30: Train Loss: 0.91 | Val Loss: 0.81 | Iou Score: 0.59 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [05:01<00:00,  2.17s/it, loss=0.6921]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.5933, loss=0.7836]
# Iteration 20/30: Train Loss: 0.91 | Val Loss: 0.87 | Iou Score: 0.56 | Dice Score: 0.71
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.8451]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6237, loss=0.7183]
# Iteration 21/30: Train Loss: 0.90 | Val Loss: 0.79 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=1.3181]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6167, loss=0.7358]
# Iteration 22/30: Train Loss: 0.90 | Val Loss: 0.82 | Iou Score: 0.58 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.15s/it, loss=0.9946]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.6201, loss=0.7309]
# Iteration 23/30: Train Loss: 0.90 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.8293]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6194, loss=0.7285]
# Iteration 24/30: Train Loss: 0.90 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=1.2002]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6291, loss=0.7074]
# Iteration 25/30: Train Loss: 0.88 | Val Loss: 0.78 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=1.0913]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6233, loss=0.7237]
# Iteration 26/30: Train Loss: 0.87 | Val Loss: 0.79 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.9991]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s, iou=0.6222, loss=0.7235]
# Iteration 27/30: Train Loss: 0.86 | Val Loss: 0.80 | Iou Score: 0.60 | Dice Score: 0.74
# Training: 100%|██████████| 139/139 [05:00<00:00,  2.16s/it, loss=0.6523]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6272, loss=0.7146]
# Iteration 28/30: Train Loss: 0.85 | Val Loss: 0.78 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.15s/it, loss=1.1577]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.35it/s, iou=0.6268, loss=0.7169]
# Iteration 29/30: Train Loss: 0.85 | Val Loss: 0.78 | Iou Score: 0.60 | Dice Score: 0.75
# Training: 100%|██████████| 139/139 [04:59<00:00,  2.16s/it, loss=0.6997]
# Evaluating: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s, iou=0.6268, loss=0.7132]
# Iteration 30/30: Train Loss: 0.85 | Val Loss: 0.78 | Iou Score: 0.60 | Dice Score: 0.75

# %% [markdown]
# Now Visualize losses.

# %% [markdown]
# ### Prediction Visualisation
#
# Display several images, their masks, and the predicted mask by your model.

# %%
plt.plot(train_losses, color="red", label="Training Loss")
plt.plot(val_losses, color="blue", label="Validation Loss")
plt.legend()
plt.show()

# %%
from collections import OrderedDict


def visualize_image_mask_prediction(images, masks, predictions, n=5):
    plt.figure(figsize=(12, 4 * n))

    for i in range(n):
        img = images[i].detach().cpu().numpy().transpose(1, 2, 0)
        
        mask = masks[i].detach().cpu().numpy().reshape(512, 512)
        pred = predictions[i].detach().cpu().numpy().reshape(512, 512)
        pred_bin = (pred > 0.5).astype(int)
        acc = (pred_bin == mask).mean() * 100

        plt.subplot(n, 3, 3 * i + 1)
        plt.imshow(img)
        plt.title(f"Image {i+1}")
        plt.axis("off")

        plt.subplot(n, 3, 3 * i + 2)
        plt.imshow(mask, cmap="gray")
        plt.title(f"Ground Truth {i+1}")
        plt.axis("off")

        plt.subplot(n, 3, 3 * i + 3)
        plt.imshow(pred, cmap="gray")
        plt.title(f"Predicted {i+1} | accuracy:{acc:.2f}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()


torch.cuda.empty_cache()
device = "cuda" if torch.cuda.is_available() else "cpu"

model = nn.DataParallel(ResidualAttentionUNet()).to(device)

ckpt = torch.load("best_residual_attention_unet.pth", map_location=device)
if isinstance(ckpt, dict) and "state_dict" in ckpt:
    ckpt = ckpt["state_dict"]

model.load_state_dict(ckpt)

model.eval()
img, masks = next(iter(train_loader))

with torch.no_grad():
    preds = model(img.to(device))

visualize_image_mask_prediction(img, masks, preds)
