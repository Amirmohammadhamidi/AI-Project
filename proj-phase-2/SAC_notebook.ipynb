# %% [markdown]
# <br>
# <font>
# <div dir=ltr align=center>
# <img src="https://cdn.freebiesupply.com/logos/large/2x/sharif-logo-png-transparent.png" width=150 height=150>
# <div dir=ltr align=center>
# <font color=0F5298 size=7>
#     Artificial Intelligence <br>
# <font color=2565AE size=5>
#     Computer Engineering Department <br>
#     Spring 2025<br>
# <font color=3C99D size=5>
#     Project-Phase2<br>
#     Soft Actor Critic<br>
# <font color=696880 size=4>
#     Ali Najar-Mohmmad Shafizade-Armin Khosravi

# %% [markdown]
# In this notebook, we are going to get familiar with SAC algorithm. Soft Actor Critic (SAC) is an off-policy algorithm that maximizes a combination of expected return **and** entropy. Higher entropy results in higher exploration, which is an important concept in Reinforcement Learning.
#
# ## 📦 Setup and Dependencies
#
# Install PyBullet for Physics based environments.

# %%
# !pip install  pybullet Box2D  gymnasium moviepy gymnasium[mujoco] gymnasium[other] git+https://github.com/benelot/pybullet-gym.git
# Out:
# Collecting git+https://github.com/benelot/pybullet-gym.git
#   Cloning https://github.com/benelot/pybullet-gym.git to /tmp/pip-req-build-cpb2x6ex
#   Running command git clone --filter=blob:none --quiet https://github.com/benelot/pybullet-gym.git /tmp/pip-req-build-cpb2x6ex
#   Resolved https://github.com/benelot/pybullet-gym.git to commit bc68201c8101c4e30dde95f425647a0709ee2f29
#   Preparing metadata (setup.py) ... done
# Collecting pybullet
#   Downloading pybullet-3.2.7.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting Box2D
#   Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (573 bytes)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.6.0)
# Collecting mujoco>=2.1.5 (from gymnasium[mujoco])
#   Downloading mujoco-3.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[mujoco]) (25.0)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[other]) (3.10.0)
# Requirement already satisfied: opencv-python>=3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[other]) (4.12.0.88)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.12/dist-packages (from gymnasium[other]) (0.13.2)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[other]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[other]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[other]) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[other]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[other]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->gymnasium[other]) (2.9.0.post0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (1.13.0)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (3.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.8.3)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.13->gymnasium[other]) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[other]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[other]) (1.17.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)
# Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 85.4 MB/s eta 0:00:00
# Downloading mujoco-3.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 127.6 MB/s eta 0:00:00
# Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 24.8 MB/s eta 0:00:00
# Building wheels for collected packages: pybullet, pybulletgym
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.7-cp312-cp312-linux_x86_64.whl size=99873169 sha256=18dcedc44e33ed5d7c8fd2a2f861c10cdd57c4e82a672edc3dbea5aacc805a34
#   Stored in directory: /root/.cache/pip/wheels/72/95/1d/b336e5ee612ae9a019bfff4dc0bedd100ee6f0570db205fdf8
#   Building wheel for pybulletgym (setup.py) ... done
#   Created wheel for pybulletgym: filename=pybulletgym-0.1-py3-none-any.whl size=1514056 sha256=73d8b97a92d0a2fcbcdc37fa38d0be335eb01e16f7fbd3820606c280ca22a289
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7kd3mw8e/wheels/db/cb/e4/6c0c9575e7608868fa2b4f24ff885eb2d3cd07875aeed71c6a
# Successfully built pybullet pybulletgym
# Installing collected packages: pybullet, glfw, Box2D, pybulletgym, mujoco
# Successfully installed Box2D-2.3.10 glfw-2.9.0 mujoco-3.3.5 pybullet-3.2.7 pybulletgym-0.1

# %% [markdown]
# Import necessary packages.

# %%
import os
import numpy as np
import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.distributions import Normal

import warnings
warnings.filterwarnings('ignore')

import gymnasium as gym
import pybulletgym

from gymnasium.wrappers import RecordVideo
from tqdm.notebook import trange
from IPython.display import Video

# compatibility fix (NumPy 2.x removed np.bool8)
np.bool8 = np.bool_
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 📈 Utility codes
#
# We will use this utility function to visualize the training progress.

# %%
def plot_learning_curve(x, filename, save_plot=True):
    avg_x = [np.mean(x[np.max([0, i - 100]):i]) for i in range(len(x))]
    plt.figure(dpi=200)
    plt.title('Learning Curve')
    plt.plot(range(len(x)), x, label='score', alpha=0.3)
    plt.plot(range(len(avg_x)), avg_x, label='average score')
    plt.xlabel('Episode')
    plt.ylabel('Score')
    plt.legend()
    plt.grid()
    if save_plot:
        plt.savefig(filename + '.png')
    plt.show()

# %% [markdown]
# This class implements a **Replay Buffer** to store and sample transitions of the form $(s_t, a_t, r_t, s_{t+1}, d_t)$ to break correlation in updates for stability in mini-batch stochastic gradient descent.

# %%
class ReplayBuffer:
    def __init__(self, buffer_size, state_dims, action_dims):
        self.buffer_size = buffer_size
        self.ptr = 0
        self.is_full = False

        # Initialize buffers
        self.states = np.zeros((buffer_size, *state_dims), dtype=np.float32)
        self.next_states = np.zeros((buffer_size, *state_dims), dtype=np.float32)
        self.actions = np.zeros((buffer_size, *action_dims), dtype=np.float32)
        self.rewards = np.zeros(buffer_size, dtype=np.float32)
        self.dones = np.zeros(buffer_size, dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        self.states[self.ptr] = state
        self.actions[self.ptr] = action
        self.rewards[self.ptr] = reward
        self.next_states[self.ptr] = state_
        self.dones[self.ptr] = done

        self.ptr += 1
        if self.ptr >= self.buffer_size:
            self.ptr = 0
            self.is_full = True

    def load_batch(self, batch_size):
        max_mem = self.buffer_size if self.is_full else self.ptr
        batch_indices = np.random.choice(max_mem, batch_size, replace=False)

        states = T.tensor(self.states[batch_indices]).float()
        actions = T.tensor(self.actions[batch_indices]).float()
        rewards = T.tensor(self.rewards[batch_indices]).float().unsqueeze(1)
        states_ = T.tensor(self.next_states[batch_indices]).float()
        done = T.tensor(self.dones[batch_indices]).float().unsqueeze(1)

        return states, actions, rewards, states_, done

# %% [markdown]
# ## 🧱 Neural Networks
#
# This cell defines three core neural networks used in SAC:
#
# - **Critic Network:**
# Estimates the **Q-value function** $ Q(s, a) $. Two critics are used to mitigate overestimation bias.
#
# - **Value Network:**
# Estimates the **state value function** $ V(s) $, used to train the actor and as a baseline.
#
# - **Actor Network:**
# Outputs the **mean** and **standard deviation** for a Gaussian policy
# $
# \pi(a|s) = \mathcal{N}(\mu(s), \sigma(s))
# $.

# %%
device = T.device('cuda' if T.cuda.is_available() else 'cpu')


class Critic(nn.Module):
    def __init__(self, beta, state_dims, action_dims, fc1_dims, fc2_dims,
                 name='Critic', ckpt_dir='agent'):
        super(Critic, self).__init__()
        # Save args
        self.state_dims = state_dims
        self.action_dims = action_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.name = name
        self.ckpt_dir = ckpt_dir
        self.ckpt_path = os.path.join(ckpt_dir, name + '.pth')

        # Define layers
        self.fc1 = nn.Linear(state_dims[0] + action_dims[0], fc1_dims)
        self.fc2 = nn.Linear(fc1_dims, fc2_dims)
        self.q = nn.Linear(fc2_dims, 1)

        # Optimizer
        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.to(device)

    def forward(self, state, action):
        x = T.cat([state, action], dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        q = self.q(x)
        return q

    def save_checkpoint(self):
        T.save(self.state_dict(), self.ckpt_path)

    def load_checkpoint(self, gpu_to_cpu=False):
        if gpu_to_cpu:
            self.load_state_dict(T.load(self.ckpt_path, map_location=lambda storage, loc: storage))
        else:
            self.load_state_dict(T.load(self.ckpt_path))


class Actor(nn.Module):
    def __init__(self, alpha, state_dims, action_dims, fc1_dims, fc2_dims,
                 max_action, reparam_noise, name='Actor', ckpt_dir='agent'):
        super(Actor, self).__init__()
        # Save args
        self.state_dims = state_dims
        self.action_dims = action_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.max_action = max_action
        self.reparam_noise = reparam_noise
        self.name = name
        self.ckpt_dir = ckpt_dir
        self.ckpt_path = os.path.join(ckpt_dir, name + '.pth')

        # Layers
        self.fc1 = nn.Linear(state_dims[0], fc1_dims)
        self.fc2 = nn.Linear(fc1_dims, fc2_dims)
        self.mu = nn.Linear(fc2_dims, action_dims[0])
        self.sigma = nn.Linear(fc2_dims, action_dims[0])

        # Optimizer
        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.to(device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        mu = self.mu(x)
        sigma = F.softplus(self.sigma(x)) + 1e-5  # Ensure positivity
        return mu, sigma

    def sample_normal(self, state, reparameterize=True):
        mu, sigma = self.forward(state)
        dist = Normal(mu, sigma)
        if reparameterize:
            action = dist.rsample()  # reparameterization trick
        else:
            action = dist.sample()
        log_probs = dist.log_prob(action).sum(dim=1, keepdim=True)
        action = T.tanh(action) * self.max_action
        return action, log_probs

    def save_checkpoint(self):
        T.save(self.state_dict(), self.ckpt_path)

    def load_checkpoint(self, gpu_to_cpu=False):
        if gpu_to_cpu:
            self.load_state_dict(T.load(self.ckpt_path, map_location=lambda storage, loc: storage))
        else:
            self.load_state_dict(T.load(self.ckpt_path))


class Value(nn.Module):
    def __init__(self, beta, state_dims, fc1_dims, fc2_dims,
                 name='Value', ckpt_dir='agent'):
        super(Value, self).__init__()
        # Save args
        self.state_dims = state_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.name = name
        self.ckpt_dir = ckpt_dir
        self.ckpt_path = os.path.join(ckpt_dir, name + '.pth')

        # Layers
        self.fc1 = nn.Linear(state_dims[0], fc1_dims)
        self.fc2 = nn.Linear(fc1_dims, fc2_dims)
        self.v = nn.Linear(fc2_dims, 1)

        # Optimizer
        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.to(device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        v = self.v(x)
        return v

    def save_checkpoint(self):
        T.save(self.state_dict(), self.ckpt_path)

    def load_checkpoint(self, gpu_to_cpu=False):
        if gpu_to_cpu:
            self.load_state_dict(T.load(self.ckpt_path, map_location=lambda storage, loc: storage))
        else:
            self.load_state_dict(T.load(self.ckpt_path))

# %% [markdown]
# ## 🤖 Agent Implementation
#
# This class encapsulates the full logic of the SAC agent. In general, the learning process uses entropy-regularized policy gradients $J_\pi = \mathbb{E}_{s_t \sim D, a_t \sim \pi} \left[ \alpha \log(\pi(a_t|s_t)) - Q(s_t, a_t) \right]$ with soft target updates $\theta_{\text{target}} \leftarrow \tau \theta + (1 - \tau)\theta_{\text{target}}$.

# %%
class Agent:
    def __init__(self, gamma, alpha, beta, state_dims, action_dims, max_action,
                 fc1_dim, fc2_dim, memory_size, batch_size, tau, update_period,
                 reward_scale, warmup, reparam_noise_lim, name, ckpt_dir='agent'):

        # --- Hyperparameters ---
        self.gamma = gamma
        self.alpha = alpha
        self.beta = beta
        self.state_dims = state_dims
        self.action_dims = action_dims
        self.max_action = max_action
        self.fc1_dim = fc1_dim
        self.fc2_dim = fc2_dim
        self.memory_size = memory_size
        self.batch_size = batch_size
        self.tau = tau
        self.update_period = update_period
        self.reward_scale = reward_scale
        self.warmup = warmup
        self.reparam_noise_lim = reparam_noise_lim
        self.ckpt_dir = ckpt_dir

        model_name = f'{name}__gamma_{gamma}__alpha_{alpha}__beta_{beta}__fc1_{fc1_dim}__fc2_{fc2_dim}__bs_{batch_size}__buffer_{memory_size}__update_period_{update_period}__tau_{tau}__'
        self.model_name = model_name
        self.full_path = os.path.join(self.ckpt_dir, self.model_name)
        self.learn_iter = 0

        # --- Replay buffer ---
        self.memory = ReplayBuffer(memory_size, state_dims, action_dims)

        # --- Actor and Critic networks ---
        self.actor = Actor(alpha, state_dims, action_dims, fc1_dim, fc2_dim,
                           max_action, reparam_noise_lim, name='actor', ckpt_dir=ckpt_dir)
        self.critic_1 = Critic(beta, state_dims, action_dims, fc1_dim, fc2_dim,
                               name='critic_1', ckpt_dir=ckpt_dir)
        self.critic_2 = Critic(beta, state_dims, action_dims, fc1_dim, fc2_dim,
                               name='critic_2', ckpt_dir=ckpt_dir)

        # --- Value and target value networks ---
        self.value = Value(beta, state_dims, fc1_dim, fc2_dim, name='value', ckpt_dir=ckpt_dir)
        self.target_value = Value(beta, state_dims, fc1_dim, fc2_dim, name='target_value', ckpt_dir=ckpt_dir)

        # --- Sync target network initially ---
        self.update_target_network(tau=1.0)

    # --- Action selection ---
    def choose_action(self, state, deterministic=False, reparameterize=False):
        state = T.tensor(state, dtype=T.float32).unsqueeze(0).to(device)
        action, _ = self.actor.sample_normal(state, reparameterize=reparameterize)
        return action.cpu().detach().numpy()[0]

    # --- Store transition in replay buffer ---
    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    # --- Sample batch from replay buffer ---
    def load_batch(self):
        return self.memory.load_batch(self.batch_size)

    # --- Soft update target network ---
    def update_target_network(self, tau=None):
        tau = self.tau if tau is None else tau
        for target_param, param in zip(self.target_value.parameters(), self.value.parameters()):
            target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

    # --- Learning step ---
    def learn(self):
        if self.memory.ptr < self.warmup:
            return  # Skip learning until enough samples collected

        states, actions, rewards, states_, dones = self.load_batch()
        states = states.to(device)
        actions = actions.to(device)
        rewards = rewards.to(device)
        states_ = states_.to(device)
        dones = dones.to(device)

        # ---------------- VALUE LOSS ----------------
        # Sample action from actor
        sampled_actions, log_probs = self.actor.sample_normal(states, reparameterize=True)

        # Estimate Q-values
        q1_val = self.critic_1(states, sampled_actions)
        q2_val = self.critic_2(states, sampled_actions)
        min_q = T.min(q1_val, q2_val)

        # Target value
        target_v = min_q - self.alpha * log_probs
        v = self.value(states)
        value_loss = F.mse_loss(v, target_v.detach())
        self.value.optimizer.zero_grad()
        value_loss.backward()
        self.value.optimizer.step()

        # ---------------- ACTOR LOSS ----------------
        new_actions, log_probs = self.actor.sample_normal(states, reparameterize=True)
        q1_new = self.critic_1(states, new_actions)
        q2_new = self.critic_2(states, new_actions)
        min_q_new = T.min(q1_new, q2_new)
        actor_loss = (self.alpha * log_probs - min_q_new).mean()
        self.actor.optimizer.zero_grad()
        actor_loss.backward()
        self.actor.optimizer.step()

        # ---------------- CRITIC LOSS ----------------
        # Compute Q target
        with T.no_grad():
            v_next = self.target_value(states_)
            q_target = self.reward_scale * rewards + self.gamma * (1 - dones) * v_next

        q1_current = self.critic_1(states, actions)
        q2_current = self.critic_2(states, actions)
        critic_1_loss = F.mse_loss(q1_current, q_target)
        critic_2_loss = F.mse_loss(q2_current, q_target)

        self.critic_1.optimizer.zero_grad()
        critic_1_loss.backward()
        self.critic_1.optimizer.step()

        self.critic_2.optimizer.zero_grad()
        critic_2_loss.backward()
        self.critic_2.optimizer.step()

        # ---------------- TARGET NETWORK UPDATE ----------------
        if self.learn_iter % self.update_period == 0:
            self.update_target_network()

        # Increment learning iteration counter
        self.learn_iter += 1
    def save_model(self):
        print('... saving checkpoint ...')
        self.actor.save_checkpoint()
        self.critic_1.save_checkpoint()
        self.critic_2.save_checkpoint()
        self.value.save_checkpoint()
        self.target_value.save_checkpoint()

    def load_model(self, gpu_to_cpu=False):
        print('... loading checkpoint ...')
        self.actor.load_checkpoint(gpu_to_cpu=gpu_to_cpu)
        self.critic_1.load_checkpoint(gpu_to_cpu=gpu_to_cpu)
        self.critic_2.load_checkpoint(gpu_to_cpu=gpu_to_cpu)
        self.value.load_checkpoint(gpu_to_cpu=gpu_to_cpu)
        self.target_value.load_checkpoint(gpu_to_cpu=gpu_to_cpu)

# %% [markdown]
# ## ⚙️ Training Configuration
#
# Set up your training parameters. `HalfCheetahBulletEnv-v0` is a continuous control task where the agent must learn to run using articulated legs.

# %%
# --- Configuration parameters ---
env_name = "HalfCheetah-v4"
env = gym.make(env_name, render_mode="rgb_array")
dir = 'agent'
n_games = 500  # Number of episodes to train

gamma = 0.99
alpha = 3e-4
beta = 3e-4
fc1_dim = 256
fc2_dim = 256
memory_size = 1000000
batch_size = 256
tau = 0.005
update_period = 2
reward_scale = 2.0
warmup = 1000
reparam_noise_lim = 1e-6
record_video = True
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(

# %% [markdown]
# ## 🚀 Training Loop
#
# For each episode, interact with the environment to collect transitions, then update the SAC networks and save the best model.
#
# After training, a learning curve is plotted to visualize convergence and performance stability.

# %%
# --- Directory setup ---
dir_path = os.path.join(dir, env_name)
os.makedirs(dir_path, exist_ok=True)

if record_video:
    env = RecordVideo(
        env,
        video_folder=os.path.join(dir_path, "videos"),
        episode_trigger=lambda ep: ep == n_games - 1,
    )

# --- Agent initialization ---
state_dims = env.observation_space.shape
action_dims = env.action_space.shape
max_action = env.action_space.high[0]

agent = Agent(
    gamma=gamma,
    alpha=alpha,
    beta=beta,
    state_dims=state_dims,
    action_dims=action_dims,
    max_action=max_action,
    fc1_dim=fc1_dim,
    fc2_dim=fc2_dim,
    memory_size=memory_size,
    batch_size=batch_size,
    tau=tau,
    update_period=update_period,
    reward_scale=reward_scale,
    warmup=warmup,
    reparam_noise_lim=reparam_noise_lim,
    name="SAC",
    ckpt_dir=dir_path,
)

# --- Performance tracking ---
scores = []
avg_scores = []
best_score = -np.inf

# --- Training loop ---
for game in trange(n_games):
    state, _ = env.reset()  # Gymnasium returns (obs, info)
    terminated = False
    truncated = False
    score = 0
    step = 0

    while not (terminated or truncated):
        action = agent.choose_action(state)
        state_, reward, terminated, truncated, info = env.step(action)

        done = terminated or truncated  # Gymnasium style
        agent.store_transition(state, action, reward, state_, done)
        agent.learn()

        state = state_
        score += reward
        step += 1

    # Track scores
    scores.append(score)
    avg_score = np.mean(scores[-100:])
    avg_scores.append(avg_score)

    # Save best model
    if avg_score > best_score:
        best_score = avg_score
        agent.save_model()

    print(
        f"| Game: {game+1:4} | Score: {score:10.2f} | Best score: {best_score:10.2f} | "
        f"Avg score {avg_score:10.2f} | Learning iter: {agent.learn_iter:6} |"
    )

env.close()

# --- Plot learning curve ---
plot_learning_curve(scores, agent.full_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# | Game:   27 | Score:    1160.71 | Best score:      -1.68 | Avg score      -1.68 | Learning iter:  26001 |
# ... saving checkpoint ...
# | Game:   28 | Score:    1342.40 | Best score:      46.33 | Avg score      46.33 | Learning iter:  27001 |
# ... saving checkpoint ...
# | Game:   29 | Score:    1503.96 | Best score:      96.59 | Avg score      96.59 | Learning iter:  28001 |
# ... saving checkpoint ...
# | Game:   30 | Score:    1297.54 | Best score:     136.62 | Avg score     136.62 | Learning iter:  29001 |
# ... saving checkpoint ...
# | Game:   31 | Score:    1444.44 | Best score:     178.81 | Avg score     178.81 | Learning iter:  30001 |
# ... saving checkpoint ...
# | Game:   32 | Score:    1615.88 | Best score:     223.72 | Avg score     223.72 | Learning iter:  31001 |
# ... saving checkpoint ...
# | Game:   33 | Score:    1892.04 | Best score:     274.27 | Avg score     274.27 | Learning iter:  32001 |
# ... saving checkpoint ...
# | Game:   34 | Score:    1851.64 | Best score:     320.67 | Avg score     320.67 | Learning iter:  33001 |
# ... saving checkpoint ...
# | Game:   35 | Score:    1925.85 | Best score:     366.53 | Avg score     366.53 | Learning iter:  34001 |
# ... saving checkpoint ...
# | Game:   36 | Score:    2067.02 | Best score:     413.76 | Avg score     413.76 | Learning iter:  35001 |
# ... saving checkpoint ...
# | Game:   37 | Score:    2085.18 | Best score:     458.94 | Avg score     458.94 | Learning iter:  36001 |
# ... saving checkpoint ...
# | Game:   38 | Score:    1957.65 | Best score:     498.38 | Avg score     498.38 | Learning iter:  37001 |
# ... saving checkpoint ...
# | Game:   39 | Score:    2093.17 | Best score:     539.27 | Avg score     539.27 | Learning iter:  38001 |
# ... saving checkpoint ...
# | Game:   40 | Score:    2038.91 | Best score:     576.76 | Avg score     576.76 | Learning iter:  39001 |
# ... saving checkpoint ...
# | Game:   41 | Score:    2109.11 | Best score:     614.13 | Avg score     614.13 | Learning iter:  40001 |
# ... saving checkpoint ...
# | Game:   42 | Score:    2085.76 | Best score:     649.17 | Avg score     649.17 | Learning iter:  41001 |
# ... saving checkpoint ...
# | Game:   43 | Score:    2069.06 | Best score:     682.19 | Avg score     682.19 | Learning iter:  42001 |
# ... saving checkpoint ...
# | Game:   44 | Score:    2089.03 | Best score:     714.17 | Avg score     714.17 | Learning iter:  43001 |
# ... saving checkpoint ...
# | Game:   45 | Score:    1972.57 | Best score:     742.13 | Avg score     742.13 | Learning iter:  44001 |
# ... saving checkpoint ...
# | Game:   46 | Score:    2236.05 | Best score:     774.61 | Avg score     774.61 | Learning iter:  45001 |
# ... saving checkpoint ...
# | Game:   47 | Score:    2122.82 | Best score:     803.29 | Avg score     803.29 | Learning iter:  46001 |
# ... saving checkpoint ...
# | Game:   48 | Score:    2034.96 | Best score:     828.95 | Avg score     828.95 | Learning iter:  47001 |
# ... saving checkpoint ...
# | Game:   49 | Score:    2008.11 | Best score:     853.02 | Avg score     853.02 | Learning iter:  48001 |
# ... saving checkpoint ...
# | Game:   50 | Score:    2203.32 | Best score:     880.02 | Avg score     880.02 | Learning iter:  49001 |
# ... saving checkpoint ...
# | Game:   51 | Score:    2036.44 | Best score:     902.70 | Avg score     902.70 | Learning iter:  50001 |
# ... saving checkpoint ...
# | Game:   52 | Score:    2076.84 | Best score:     925.28 | Avg score     925.28 | Learning iter:  51001 |
# ... saving checkpoint ...
# | Game:   53 | Score:    2138.94 | Best score:     948.18 | Avg score     948.18 | Learning iter:  52001 |
# ... saving checkpoint ...
# | Game:   54 | Score:    2015.74 | Best score:     967.95 | Avg score     967.95 | Learning iter:  53001 |
# ... saving checkpoint ...
# | Game:   55 | Score:    2087.57 | Best score:     988.30 | Avg score     988.30 | Learning iter:  54001 |
# ... saving checkpoint ...
# | Game:   56 | Score:    2006.82 | Best score:    1006.49 | Avg score    1006.49 | Learning iter:  55001 |
# ... saving checkpoint ...
# | Game:   57 | Score:    2171.88 | Best score:    1026.94 | Avg score    1026.94 | Learning iter:  56001 |
# ... saving checkpoint ...
# | Game:   58 | Score:    2152.87 | Best score:    1046.35 | Avg score    1046.35 | Learning iter:  57001 |
# ... saving checkpoint ...
# | Game:   59 | Score:    2146.44 | Best score:    1065.00 | Avg score    1065.00 | Learning iter:  58001 |
# ... saving checkpoint ...
# | Game:   60 | Score:    2109.41 | Best score:    1082.40 | Avg score    1082.40 | Learning iter:  59001 |
# ... saving checkpoint ...
# | Game:   61 | Score:    2392.73 | Best score:    1103.88 | Avg score    1103.88 | Learning iter:  60001 |
# ... saving checkpoint ...
# | Game:   62 | Score:    2135.65 | Best score:    1120.52 | Avg score    1120.52 | Learning iter:  61001 |
# ... saving checkpoint ...
# | Game:   63 | Score:    1981.27 | Best score:    1134.19 | Avg score    1134.19 | Learning iter:  62001 |
# ... saving checkpoint ...
# | Game:   64 | Score:    2238.97 | Best score:    1151.45 | Avg score    1151.45 | Learning iter:  63001 |
# ... saving checkpoint ...
# | Game:   65 | Score:    2171.35 | Best score:    1167.14 | Avg score    1167.14 | Learning iter:  64001 |
# ... saving checkpoint ...
# | Game:   66 | Score:    2135.71 | Best score:    1181.82 | Avg score    1181.82 | Learning iter:  65001 |
# ... saving checkpoint ...
# | Game:   67 | Score:    2034.62 | Best score:    1194.54 | Avg score    1194.54 | Learning iter:  66001 |
# ... saving checkpoint ...
# | Game:   68 | Score:    2019.62 | Best score:    1206.68 | Avg score    1206.68 | Learning iter:  67001 |
# ... saving checkpoint ...
# | Game:   69 | Score:    2228.24 | Best score:    1221.48 | Avg score    1221.48 | Learning iter:  68001 |
# ... saving checkpoint ...
# | Game:   70 | Score:    2163.87 | Best score:    1234.95 | Avg score    1234.95 | Learning iter:  69001 |
# ... saving checkpoint ...
# | Game:   71 | Score:    2341.56 | Best score:    1250.53 | Avg score    1250.53 | Learning iter:  70001 |
# ... saving checkpoint ...
# | Game:   72 | Score:    2231.23 | Best score:    1264.15 | Avg score    1264.15 | Learning iter:  71001 |
# ... saving checkpoint ...
# | Game:   73 | Score:    2077.19 | Best score:    1275.29 | Avg score    1275.29 | Learning iter:  72001 |
# ... saving checkpoint ...
# | Game:   74 | Score:    2154.97 | Best score:    1287.18 | Avg score    1287.18 | Learning iter:  73001 |
# ... saving checkpoint ...
# | Game:   75 | Score:    1992.33 | Best score:    1296.58 | Avg score    1296.58 | Learning iter:  74001 |
# ... saving checkpoint ...
# | Game:   76 | Score:    2090.48 | Best score:    1307.03 | Avg score    1307.03 | Learning iter:  75001 |
# ... saving checkpoint ...
# | Game:   77 | Score:    2069.54 | Best score:    1316.93 | Avg score    1316.93 | Learning iter:  76001 |
# ... saving checkpoint ...
# | Game:   78 | Score:    2075.15 | Best score:    1326.65 | Avg score    1326.65 | Learning iter:  77001 |
# ... saving checkpoint ...
# | Game:   79 | Score:    2021.70 | Best score:    1335.45 | Avg score    1335.45 | Learning iter:  78001 |
# ... saving checkpoint ...
# | Game:   80 | Score:    2188.18 | Best score:    1346.11 | Avg score    1346.11 | Learning iter:  79001 |
# ... saving checkpoint ...
# | Game:   81 | Score:    2114.99 | Best score:    1355.60 | Avg score    1355.60 | Learning iter:  80001 |
# ... saving checkpoint ...
# | Game:   82 | Score:    2395.80 | Best score:    1368.28 | Avg score    1368.28 | Learning iter:  81001 |
# ... saving checkpoint ...
# | Game:   83 | Score:    2352.25 | Best score:    1380.14 | Avg score    1380.14 | Learning iter:  82001 |
# ... saving checkpoint ...
# | Game:   84 | Score:    2196.36 | Best score:    1389.86 | Avg score    1389.86 | Learning iter:  83001 |
# ... saving checkpoint ...
# | Game:   85 | Score:    2164.17 | Best score:    1398.97 | Avg score    1398.97 | Learning iter:  84001 |
# ... saving checkpoint ...
# | Game:   86 | Score:    2308.62 | Best score:    1409.54 | Avg score    1409.54 | Learning iter:  85001 |
# ... saving checkpoint ...
# | Game:   87 | Score:    2214.49 | Best score:    1418.80 | Avg score    1418.80 | Learning iter:  86001 |
# ... saving checkpoint ...
# | Game:   88 | Score:    2267.85 | Best score:    1428.44 | Avg score    1428.44 | Learning iter:  87001 |
# ... saving checkpoint ...
# | Game:   89 | Score:    2315.08 | Best score:    1438.41 | Avg score    1438.41 | Learning iter:  88001 |
# ... saving checkpoint ...
# | Game:   90 | Score:    2345.21 | Best score:    1448.48 | Avg score    1448.48 | Learning iter:  89001 |
# ... saving checkpoint ...
# | Game:   91 | Score:    2328.23 | Best score:    1458.15 | Avg score    1458.15 | Learning iter:  90001 |
# ... saving checkpoint ...
# | Game:   92 | Score:    2077.67 | Best score:    1464.88 | Avg score    1464.88 | Learning iter:  91001 |
# ... saving checkpoint ...
# | Game:   93 | Score:    2300.40 | Best score:    1473.87 | Avg score    1473.87 | Learning iter:  92001 |
# ... saving checkpoint ...
# | Game:   94 | Score:    2053.71 | Best score:    1480.04 | Avg score    1480.04 | Learning iter:  93001 |
# ... saving checkpoint ...
# | Game:   95 | Score:    2362.23 | Best score:    1489.32 | Avg score    1489.32 | Learning iter:  94001 |
# ... saving checkpoint ...
# | Game:   96 | Score:    2373.14 | Best score:    1498.53 | Avg score    1498.53 | Learning iter:  95001 |
# ... saving checkpoint ...
# | Game:   97 | Score:    2225.27 | Best score:    1506.02 | Avg score    1506.02 | Learning iter:  96001 |
# ... saving checkpoint ...
# | Game:   98 | Score:    2126.94 | Best score:    1512.36 | Avg score    1512.36 | Learning iter:  97001 |
# ... saving checkpoint ...
# | Game:  340 | Score:    3186.98 | Best score:    2964.04 | Avg score    2964.04 | Learning iter: 339001 |
# ... saving checkpoint ...
# | Game:  341 | Score:    3154.63 | Best score:    2970.14 | Avg score    2970.14 | Learning iter: 340001 |
# ... saving checkpoint ...
# | Game:  342 | Score:    3082.32 | Best score:    2974.99 | Avg score    2974.99 | Learning iter: 341001 |
# ... saving checkpoint ...
# | Game:  343 | Score:    3229.79 | Best score:    2980.52 | Avg score    2980.52 | Learning iter: 342001 |
# ... saving checkpoint ...
# | Game:  344 | Score:    3114.72 | Best score:    2984.58 | Avg score    2984.58 | Learning iter: 343001 |
# ... saving checkpoint ...
# | Game:  345 | Score:    3184.98 | Best score:    2989.34 | Avg score    2989.34 | Learning iter: 344001 |
# ... saving checkpoint ...
# | Game:  346 | Score:    3208.48 | Best score:    2993.21 | Avg score    2993.21 | Learning iter: 345001 |
# ... saving checkpoint ...
# | Game:  347 | Score:    3199.20 | Best score:    2998.93 | Avg score    2998.93 | Learning iter: 346001 |
# ... saving checkpoint ...
# | Game:  348 | Score:    3227.94 | Best score:    3002.94 | Avg score    3002.94 | Learning iter: 347001 |
# ... saving checkpoint ...
# | Game:  349 | Score:    3014.79 | Best score:    3005.49 | Avg score    3005.49 | Learning iter: 348001 |
# ... saving checkpoint ...
# | Game:  350 | Score:    3051.73 | Best score:    3009.60 | Avg score    3009.60 | Learning iter: 349001 |
# ... saving checkpoint ...
# | Game:  351 | Score:    3222.45 | Best score:    3015.80 | Avg score    3015.80 | Learning iter: 350001 |
# ... saving checkpoint ...
# | Game:  352 | Score:    3309.49 | Best score:    3021.26 | Avg score    3021.26 | Learning iter: 351001 |
# ... saving checkpoint ...
# | Game:  353 | Score:    3242.39 | Best score:    3025.22 | Avg score    3025.22 | Learning iter: 352001 |
# ... saving checkpoint ...
# | Game:  354 | Score:    3171.76 | Best score:    3028.82 | Avg score    3028.82 | Learning iter: 353001 |
# ... saving checkpoint ...
# | Game:  355 | Score:    3252.27 | Best score:    3034.28 | Avg score    3034.28 | Learning iter: 354001 |
# ... saving checkpoint ...
# | Game:  356 | Score:    2999.87 | Best score:    3035.50 | Avg score    3035.50 | Learning iter: 355001 |
# ... saving checkpoint ...
# | Game:  357 | Score:    3076.44 | Best score:    3038.89 | Avg score    3038.89 | Learning iter: 356001 |
# ... saving checkpoint ...
# | Game:  358 | Score:    3239.05 | Best score:    3043.33 | Avg score    3043.33 | Learning iter: 357001 |
# ... saving checkpoint ...
# | Game:  359 | Score:    3305.00 | Best score:    3045.59 | Avg score    3045.59 | Learning iter: 358001 |
# ... saving checkpoint ...
# | Game:  360 | Score:    3225.13 | Best score:    3049.21 | Avg score    3049.21 | Learning iter: 359001 |
# ... saving checkpoint ...
# | Game:  361 | Score:    3260.15 | Best score:    3052.49 | Avg score    3052.49 | Learning iter: 360001 |
# ... saving checkpoint ...
# | Game:  362 | Score:    3240.98 | Best score:    3056.09 | Avg score    3056.09 | Learning iter: 361001 |
# ... saving checkpoint ...
# | Game:  363 | Score:    3137.22 | Best score:    3057.80 | Avg score    3057.80 | Learning iter: 362001 |
# ... saving checkpoint ...
# | Game:  364 | Score:    3353.99 | Best score:    3062.42 | Avg score    3062.42 | Learning iter: 363001 |
# ... saving checkpoint ...
# | Game:  365 | Score:    3140.41 | Best score:    3064.99 | Avg score    3064.99 | Learning iter: 364001 |
# ... saving checkpoint ...
# | Game:  366 | Score:    3099.68 | Best score:    3066.17 | Avg score    3066.17 | Learning iter: 365001 |
# ... saving checkpoint ...
# | Game:  367 | Score:    3178.03 | Best score:    3069.59 | Avg score    3069.59 | Learning iter: 366001 |
# ... saving checkpoint ...
# ...
# ... saving checkpoint ...
# | Game:  413 | Score:    3233.39 | Best score:    3219.16 | Avg score    3219.16 | Learning iter: 412001 |
# ... saving checkpoint ...
# | Game:  414 | Score:    3337.93 | Best score:    3221.16 | Avg score    3221.16 | Learning iter: 413001 |
# ... saving checkpoint ...
# | Game:  415 | Score:    3258.23 | Best score:    3222.17 | Avg score    3222.17 | Learning iter: 414001 |
# ... saving checkpoint ...
# | Game:  416 | Score:    3350.30 | Best score:    3224.53 | Avg score    3224.53 | Learning iter: 415001 |
# ... saving checkpoint ...
# | Game:  417 | Score:    3372.13 | Best score:    3227.36 | Avg score    3227.36 | Learning iter: 416001 |
# ... saving checkpoint ...
# | Game:  418 | Score:    3385.22 | Best score:    3229.20 | Avg score    3229.20 | Learning iter: 417001 |
# ... saving checkpoint ...
# | Game:  419 | Score:    3401.63 | Best score:    3231.33 | Avg score    3231.33 | Learning iter: 418001 |
# ... saving checkpoint ...
# | Game:  420 | Score:    3397.54 | Best score:    3235.22 | Avg score    3235.22 | Learning iter: 419001 |
# ... saving checkpoint ...
# | Game:  421 | Score:    3256.28 | Best score:    3235.60 | Avg score    3235.60 | Learning iter: 420001 |
# ... saving checkpoint ...
# | Game:  422 | Score:    3329.16 | Best score:    3237.55 | Avg score    3237.55 | Learning iter: 421001 |
# ... saving checkpoint ...
# | Game:  423 | Score:    3376.25 | Best score:    3239.08 | Avg score    3239.08 | Learning iter: 422001 |
# ... saving checkpoint ...
# | Game:  424 | Score:    3438.35 | Best score:    3241.60 | Avg score    3241.60 | Learning iter: 423001 |
# ... saving checkpoint ...
# | Game:  425 | Score:    3364.75 | Best score:    3243.00 | Avg score    3243.00 | Learning iter: 424001 |
# ... saving checkpoint ...
# | Game:  426 | Score:    3424.66 | Best score:    3245.78 | Avg score    3245.78 | Learning iter: 425001 |
# ... saving checkpoint ...
# | Game:  427 | Score:    3292.99 | Best score:    3248.34 | Avg score    3248.34 | Learning iter: 426001 |
# | Game:  428 | Score:    3264.81 | Best score:    3248.34 | Avg score    3247.57 | Learning iter: 427001 |
# ... saving checkpoint ...
# | Game:  429 | Score:    3198.47 | Best score:    3248.47 | Avg score    3248.47 | Learning iter: 428001 |
# ... saving checkpoint ...
# | Game:  430 | Score:    3336.05 | Best score:    3249.40 | Avg score    3249.40 | Learning iter: 429001 |
# ... saving checkpoint ...
# | Game:  431 | Score:    3487.54 | Best score:    3252.56 | Avg score    3252.56 | Learning iter: 430001 |
# ... saving checkpoint ...
# | Game:  480 | Score:    3501.89 | Best score:    3348.09 | Avg score    3348.09 | Learning iter: 479001 |
# ... saving checkpoint ...
# | Game:  481 | Score:    3374.22 | Best score:    3349.69 | Avg score    3349.69 | Learning iter: 480001 |
# ... saving checkpoint ...
# | Game:  482 | Score:    3446.96 | Best score:    3350.52 | Avg score    3350.52 | Learning iter: 481001 |
# ... saving checkpoint ...
# | Game:  483 | Score:    3443.25 | Best score:    3352.40 | Avg score    3352.40 | Learning iter: 482001 |
# ... saving checkpoint ...
# | Game:  484 | Score:    3472.55 | Best score:    3354.36 | Avg score    3354.36 | Learning iter: 483001 |
# | Game:  485 | Score:    3318.81 | Best score:    3354.36 | Avg score    3354.27 | Learning iter: 484001 |
# ... saving checkpoint ...
# | Game:  486 | Score:    3374.78 | Best score:    3355.23 | Avg score    3355.23 | Learning iter: 485001 |
# ... saving checkpoint ...
# | Game:  487 | Score:    3577.65 | Best score:    3357.86 | Avg score    3357.86 | Learning iter: 486001 |
# ... saving checkpoint ...
# | Game:  488 | Score:    3427.30 | Best score:    3358.50 | Avg score    3358.50 | Learning iter: 487001 |
# ... saving checkpoint ...
# | Game:  489 | Score:    3569.73 | Best score:    3359.79 | Avg score    3359.79 | Learning iter: 488001 |
# ... saving checkpoint ...
# | Game:  490 | Score:    3387.48 | Best score:    3361.29 | Avg score    3361.29 | Learning iter: 489001 |
# ... saving checkpoint ...
# | Game:  491 | Score:    3420.19 | Best score:    3362.55 | Avg score    3362.55 | Learning iter: 490001 |
# ... saving checkpoint ...
# | Game:  492 | Score:    3377.90 | Best score:    3363.11 | Avg score    3363.11 | Learning iter: 491001 |
# ... saving checkpoint ...
# | Game:  493 | Score:    3382.13 | Best score:    3363.84 | Avg score    3363.84 | Learning iter: 492001 |
# ... saving checkpoint ...
# | Game:  494 | Score:    3500.09 | Best score:    3366.55 | Avg score    3366.55 | Learning iter: 493001 |
# ... saving checkpoint ...
# | Game:  495 | Score:    3483.88 | Best score:    3367.65 | Avg score    3367.65 | Learning iter: 494001 |
# ... saving checkpoint ...
# | Game:  496 | Score:    3354.85 | Best score:    3368.36 | Avg score    3368.36 | Learning iter: 495001 |
# ... saving checkpoint ...
# | Game:  497 | Score:    3438.45 | Best score:    3371.14 | Avg score    3371.14 | Learning iter: 496001 |
# | Game:  498 | Score:    3338.27 | Best score:    3371.14 | Avg score    3369.85 | Learning iter: 497001 |
# ... saving checkpoint ...
# | Game:  499 | Score:    3341.20 | Best score:    3371.36 | Avg score    3371.36 | Learning iter: 498001 |
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# /tmp/ipython-input-601184224.py in <cell line: 0>()
#      42 # --- Training loop ---
#      43 for game in trange(n_games):
# ---> 44     state, _ = env.reset()  # Gymnasium returns (obs, info)
#      45     terminated = False
#      46     truncated = False
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py in reset(self, seed, options)
#     351             self.start_recording(f"{self.name_prefix}-episode-{self.episode_id}")
#     352         if self.recording:
# --> 353             self._capture_frame()
#     354             if len(self.recorded_frames) > self.video_length:
#     355                 self.stop_recording()
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py in _capture_frame(self)
#     323         assert self.recording, "Cannot capture a frame, recording wasn't started."
#     324
# --> 325         frame = self.env.render()
#     326         if isinstance(frame, list):
#     327             if len(frame) == 0:  # render was called
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/core.py in render(self)
#     335     def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336         """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337         return self.env.render()
#     338
#     339     def close(self):
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/common.py in render(self)
#     407                 "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408             )
# --> 409         return super().render()
#     410
#     411     @property
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/core.py in render(self)
#     335     def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336         """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337         return self.env.render()
#     338
#     339     def close(self):
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/common.py in render(self)
#     299         if self.checked_render is False:
#     300             self.checked_render = True
# --> 301             return env_render_passive_checker(self.env)
#     302         else:
#     303             return self.env.render()
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/utils/passive_env_checker.py in env_render_passive_checker(env)
#     359             )
#     360
# --> 361     result = env.render()
#     362     if env.render_mode is not None:
#     363         _check_render_return(env.render_mode, result)
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/mujoco/mujoco_env.py in render(self)
#     156         Render a frame from the MuJoCo simulation as specified by the render_mode.
#     157         """
# --> 158         return self.mujoco_renderer.render(self.render_mode)
#     159
#     160     def close(self):
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/mujoco/mujoco_rendering.py in render(self, render_mode)
#     759             ), f"The width: {self.width} and height: {self.height} cannot be `None` when the render_mode is not `human`."
#     760
# --> 761         viewer = self._get_viewer(render_mode=render_mode)
#     762
#     763         if render_mode in ["rgb_array", "depth_array", "rgbd_tuple"]:
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/mujoco/mujoco_rendering.py in _get_viewer(self, render_mode)
#     783                 )
#     784             elif render_mode in {"rgb_array", "depth_array", "rgbd_tuple"}:
# --> 785                 self.viewer = OffScreenViewer(
#     786                     self.model,
#     787                     self.data,
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/mujoco/mujoco_rendering.py in __init__(self, model, data, width, height, max_geom, visual_options)
#     187         self._get_opengl_backend(width, height)
#     188
# --> 189         super().__init__(model, data, width, height, max_geom, visual_options)
#     190
#     191         self._init_camera()
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/mujoco/mujoco_rendering.py in __init__(self, model, data, width, height, max_geom, visual_options)
#      72
#      73         # Keep in Mujoco Context
# ---> 74         self.con = mujoco.MjrContext(self.model, mujoco.mjtFontScale.mjFONTSCALE_150)
#      75
#      76         self._set_mujoco_buffer()
#
# FatalError: gladLoadGL error

# %%
plot_learning_curve(scores, agent.full_path)
